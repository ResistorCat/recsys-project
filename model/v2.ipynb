# %% [markdown]
# # Modelo V2

# %%
# FLAGS
FLAG_DATASET_DL = False

# %% [markdown]
# ## 1. Carga de datos y librerías

# %%
# Actualizar pip
# %pip install --upgrade pip
# Dependencias para graficar y manipular datos
# %pip install pandas matplotlib tqdm seaborn ipywidgets
# Dependencias para leer archivos Parquet
# %pip install pyarrow fastparquet
# Para predicción
# %pip install scikit-learn lightfm recommenders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/vscode/.local/lib/python3.10/site-packages (25.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/vscode/.local/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/vscode/.local/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: tqdm in /home/vscode/.local/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: seaborn in /home/vscode/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: ipywidgets in /home/vscode/.local/lib/python3.10/site-packages (8.1.7)
# Requirement already satisfied: numpy>=1.22.4 in /home/vscode/.local/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: comm>=0.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/vscode/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.14.0)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/vscode/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in /home/vscode/.local/lib/python3.10/site-packages (20.0.0)
# Requirement already satisfied: fastparquet in /home/vscode/.local/lib/python3.10/site-packages (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from fastparquet) (2.2.3)
# Requirement already satisfied: numpy in /home/vscode/.local/lib/python3.10/site-packages (from fastparquet) (2.2.6)
# Requirement already satisfied: cramjam>=2.3 in /home/vscode/.local/lib/python3.10/site-packages (from fastparquet) (2.10.0)
# Requirement already satisfied: fsspec in /home/vscode/.local/lib/python3.10/site-packages (from fastparquet) (2025.5.1)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.10/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/vscode/.local/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: lightfm in /home/vscode/.local/lib/python3.10/site-packages (1.17)
# Requirement already satisfied: recommenders in /home/vscode/.local/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.10/site-packages (from lightfm) (2.32.3)
# Requirement already satisfied: category-encoders<3,>=2.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (2.8.1)
# Requirement already satisfied: cornac<3,>=1.15.2 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (2.3.3)
# Requirement already satisfied: hyperopt<1,>=0.2.7 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (0.2.7)
# Requirement already satisfied: lightgbm<5,>=4.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (4.6.0)
# Requirement already satisfied: locust<3,>=2.12.2 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (2.37.9)
# Requirement already satisfied: memory-profiler<1,>=0.61.0 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (0.61.0)
# Requirement already satisfied: nltk<4,>=3.8.1 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (3.9.1)
# Requirement already satisfied: notebook<8,>=6.5.5 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (7.4.3)
# Requirement already satisfied: numba<1,>=0.57.0 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (0.61.2)
# Requirement already satisfied: pandas<3.0.0,>2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (2.2.3)
# Requirement already satisfied: retrying<2,>=1.3.4 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (1.3.4)
# Requirement already satisfied: scikit-surprise>=1.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (1.1.4)
# Requirement already satisfied: seaborn<1,>=0.13.0 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (0.13.2)
# Requirement already satisfied: transformers<5,>=4.27.0 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (4.52.4)
# Requirement already satisfied: pandera>=0.15.0 in /home/vscode/.local/lib/python3.10/site-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.24.0)
# Requirement already satisfied: statsmodels>=0.14.4 in /home/vscode/.local/lib/python3.10/site-packages (from recommenders) (0.14.4)
# Requirement already satisfied: patsy>=0.5.1 in /home/vscode/.local/lib/python3.10/site-packages (from category-encoders<3,>=2.6.0->recommenders) (1.0.1)
# Requirement already satisfied: tqdm in /home/vscode/.local/lib/python3.10/site-packages (from cornac<3,>=1.15.2->recommenders) (4.67.1)
# Requirement already satisfied: powerlaw in /home/vscode/.local/lib/python3.10/site-packages (from cornac<3,>=1.15.2->recommenders) (1.5)
# Requirement already satisfied: six in /home/vscode/.local/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in /home/vscode/.local/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (3.4.2)
# Requirement already satisfied: future in /home/vscode/.local/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (1.0.0)
# Requirement already satisfied: cloudpickle in /home/vscode/.local/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (3.1.1)
# Requirement already satisfied: py4j in /home/vscode/.local/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (0.10.9.9)
# Requirement already satisfied: configargparse>=1.7.1 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (1.7.1)
# Requirement already satisfied: flask-cors>=3.0.10 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (6.0.0)
# Requirement already satisfied: flask-login>=0.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (0.6.3)
# Requirement already satisfied: flask>=2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (3.1.1)
# Requirement already satisfied: gevent<26.0.0,>=24.10.1 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (25.5.1)
# Requirement already satisfied: geventhttpclient>=2.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (2.3.3)
# Requirement already satisfied: locust-cloud>=1.23.1 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (1.23.1)
# Requirement already satisfied: msgpack>=1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: psutil>=5.9.1 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (7.0.0)
# Requirement already satisfied: pyzmq>=25.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (26.4.0)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (75.6.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (4.14.0)
# Requirement already satisfied: werkzeug>=2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (3.1.3)
# Requirement already satisfied: greenlet>=3.2.2 in /home/vscode/.local/lib/python3.10/site-packages (from gevent<26.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (3.2.3)
# Requirement already satisfied: zope.event in /home/vscode/.local/lib/python3.10/site-packages (from gevent<26.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (5.0)
# Requirement already satisfied: zope.interface in /home/vscode/.local/lib/python3.10/site-packages (from gevent<26.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (7.2)
# Requirement already satisfied: click in /home/vscode/.local/lib/python3.10/site-packages (from nltk<4,>=3.8.1->recommenders) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/vscode/.local/lib/python3.10/site-packages (from nltk<4,>=3.8.1->recommenders) (2024.11.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/vscode/.local/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (4.4.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/vscode/.local/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (6.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/vscode/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (4.24.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/vscode/.local/lib/python3.10/site-packages (from numba<1,>=0.57.0->recommenders) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.10/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/vscode/.local/lib/python3.10/site-packages (from seaborn<1,>=0.13.0->recommenders) (3.10.3)
# Requirement already satisfied: filelock in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (0.32.4)
# Requirement already satisfied: pyyaml>=5.1 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5,>=4.27.0->recommenders) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5,>=4.27.0->recommenders) (1.1.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/vscode/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /home/vscode/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/vscode/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/vscode/.local/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (21.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (3.0.2)
# Requirement already satisfied: certifi in /home/vscode/.local/lib/python3.10/site-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (2025.4.26)
# Requirement already satisfied: brotli in /home/vscode/.local/lib/python3.10/site-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: urllib3 in /home/vscode/.local/lib/python3.10/site-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (2.4.0)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.16.0)
# Requirement already satisfied: comm>=0.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (8.37.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/vscode/.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (1.6.0)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (2.19.1)
# Requirement already satisfied: stack_data in /home/vscode/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.6.3)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/vscode/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (0.25.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.3.8)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.1.1)
# Requirement already satisfied: fqdn in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.5.1)
# Requirement already satisfied: isoduration in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.0.0)
# Requirement already satisfied: uri-template in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (24.11.1)
# Requirement already satisfied: python-engineio>=4.12.2 in /home/vscode/.local/lib/python3.10/site-packages (from locust-cloud>=1.23.1->locust<3,>=2.12.2->recommenders) (4.12.2)
# Requirement already satisfied: python-socketio==5.13.0 in /home/vscode/.local/lib/python3.10/site-packages (from python-socketio[client]==5.13.0->locust-cloud>=1.23.1->locust<3,>=2.12.2->recommenders) (5.13.0)
# Requirement already satisfied: bidict>=0.21.0 in /home/vscode/.local/lib/python3.10/site-packages (from python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.23.1->locust<3,>=2.12.2->recommenders) (0.23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (3.2.3)
# Requirement already satisfied: beautifulsoup4 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (6.2.0)
# Requirement already satisfied: defusedxml in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.5.1)
# Requirement already satisfied: webencodings in /home/vscode/.local/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/vscode/.local/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.21.1)
# Requirement already satisfied: pydantic in /home/vscode/.local/lib/python3.10/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.11.5)
# Requirement already satisfied: typeguard in /home/vscode/.local/lib/python3.10/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (4.4.3)
# Requirement already satisfied: typing_inspect>=0.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.9.0)
# Requirement already satisfied: hypothesis>=6.92.7 in /home/vscode/.local/lib/python3.10/site-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (6.135.1)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vscode/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.7.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /home/vscode/.local/lib/python3.10/site-packages (from python-engineio>=4.12.2->locust-cloud>=1.23.1->locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests->lightfm) (3.4.2)
# Requirement already satisfied: wsproto in /home/vscode/.local/lib/python3.10/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.12.2->locust-cloud>=1.23.1->locust<3,>=2.12.2->recommenders) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from typing_inspect>=0.6.0->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (1.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.17.1)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /home/vscode/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /home/vscode/.local/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/vscode/.local/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.9.0.20250516)
# Requirement already satisfied: mpmath in /home/vscode/.local/lib/python3.10/site-packages (from powerlaw->cornac<3,>=1.15.2->recommenders) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (3.0.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.3->notebook<8,>=6.5.5->recommenders) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar librerías globales

# Manejo de datos y visualización
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from tqdm.auto import tqdm

# Crear directorios
PATH_DATASETS = "datasets"
PATH_DATASETS_FOODCOM = os.path.join(PATH_DATASETS, "foodcom")
os.makedirs(PATH_DATASETS, exist_ok=True)

# %%
if FLAG_DATASET_DL:
  # Descargar "Recipes and Reviews" de Food.com
  os.system(f"curl -L -o {PATH_DATASETS_FOODCOM}.zip https://www.kaggle.com/api/v1/datasets/download/irkaal/foodcom-recipes-and-reviews")
  os.system(f"unzip -o {PATH_DATASETS_FOODCOM}.zip -d {PATH_DATASETS_FOODCOM}")
  # Eliminar el zip
  os.remove(f"{PATH_DATASETS_FOODCOM}.zip")

  # Cita: Dominio público (https://www.kaggle.com/datasets/irkaal/foodcom-recipes-and-reviews)

# %%
# Foodcom dataframes
df_foodcom_recipes = pd.read_parquet(os.path.join(PATH_DATASETS_FOODCOM, "recipes.parquet"))
df_foodcom_reviews = pd.read_parquet(os.path.join(PATH_DATASETS_FOODCOM, "reviews.parquet"))

# %% [markdown]
# ## 2. Preprocesamiento de datos

# %% [markdown]
# ### 2.1. Food.com
#
# En df_foodcom_reviews:
# - "AuthorId" -> "user_id" (int)
# - "RecipeId" -> "recipe_id" (int)
# - "Rating" -> "rating" (float)

# %%
df_ratings = df_foodcom_reviews.rename(columns={
    'AuthorId': 'user_id',
    'RecipeId': 'recipe_id',
    'Rating'  : 'rating'
})[['user_id', 'recipe_id', 'rating']]

df_ratings['user_id']   = df_ratings['user_id'].astype(np.int32)
df_ratings['recipe_id'] = df_ratings['recipe_id'].astype(np.int32)
df_ratings['rating']    = df_ratings['rating'].astype(np.int8)

# Mostrar información del dataframe de ratings
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401982 entries, 0 to 1401981
# Data columns (total 3 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1401982 non-null  int32
#  1   recipe_id  1401982 non-null  int32
#  2   rating     1401982 non-null  int8
# dtypes: int32(2), int8(1)
# memory usage: 12.0 MB

# %% [markdown]
# En df_foodcom_recipes:
# - "RecipeId" -> "recipe_id" (int)

# %%
df_recipes = df_foodcom_recipes.rename(columns={
    'RecipeId': 'recipe_id'
}).copy()

df_recipes['recipe_id'] = df_recipes['recipe_id'].astype(int)

# Mostrar información del dataframe de recetas
df_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   recipe_id                   522517 non-null  int64
#  1   Name                        522517 non-null  object
#  2   AuthorId                    522517 non-null  int32
#  3   AuthorName                  522517 non-null  object
#  4   CookTime                    439972 non-null  object
#  5   PrepTime                    522517 non-null  object
#  6   TotalTime                   522517 non-null  object
#  7   DatePublished               522517 non-null  datetime64[us, UTC]
#  8   Description                 522512 non-null  object
#  9   Images                      522516 non-null  object
#  10  RecipeCategory              521766 non-null  object
#  11  Keywords                    522517 non-null  object
#  12  RecipeIngredientQuantities  522517 non-null  object
#  13  RecipeIngredientParts       522517 non-null  object
#  14  AggregatedRating            269294 non-null  float64
#  15  ReviewCount                 275028 non-null  float64
#  16  Calories                    522517 non-null  float64
#  17  FatContent                  522517 non-null  float64
#  18  SaturatedFatContent         522517 non-null  float64
#  19  CholesterolContent          522517 non-null  float64
#  20  SodiumContent               522517 non-null  float64
#  21  CarbohydrateContent         522517 non-null  float64
#  22  FiberContent                522517 non-null  float64
#  23  SugarContent                522517 non-null  float64
#  24  ProteinContent              522517 non-null  float64
#  25  RecipeServings              339606 non-null  float64
#  26  RecipeYield                 174446 non-null  object
#  27  RecipeInstructions          522517 non-null  object
# dtypes: datetime64[us, UTC](1), float64(12), int32(1), int64(1), object(13)
# memory usage: 109.6+ MB

# %% [markdown]
# ## 3. Modelo

# %%
# ===============================================================
# Híbrido con LightFM (colaborative + metadata)
# ===============================================================
from lightfm import LightFM
from lightfm.data import Dataset
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k, recall_at_k
from recommenders.utils.timer import Timer


class FoodRecommenderV2:
    """
    Recomendador híbrido que combina LightFM con metadatos de recetas.
    Utiliza un modelo de LightFM entrenado con WARP (Weighted Approximate-Rank Pairwise).
    """

    def __init__(self, df_ratings: pd.DataFrame, df_recipes: pd.DataFrame, verbose: bool = False, test_percentage: float = 0.25):
        self.verbose = verbose
        # Filtramos los ratings para evitar sparsity extrema
        user_filter = df_ratings['user_id'].value_counts() >= 10
        recipe_filter = df_ratings['recipe_id'].value_counts() >= 10
        self.df_ratings = df_ratings[
            df_ratings['user_id'].isin(user_filter[user_filter].index) &
            df_ratings['recipe_id'].isin(recipe_filter[recipe_filter].index)
        ].copy()

        self.log(f"Ratings filtrados: {len(self.df_ratings):,}")
    
        # Obtenemos los metadatos de recetas
        # TODO: Incluir metadatos de recetas como ingredientes, categorías, etc.
        
        # Creamos el dataset de LightFM
        self.dataset = Dataset()
        self.dataset.fit(
            users=df_ratings['user_id'].unique(),
            items=df_ratings['recipe_id'].unique()
        )
        self.num_users, self.num_items = self.dataset.interactions_shape()
        self.log(f"Dataset creado con {self.num_users:,} usuarios y {self.num_items:,} recetas.")

        # Creamos las interacciones
        self.interactions, self.weights = self.dataset.build_interactions(self.df_ratings[['user_id', 'recipe_id', 'rating']].to_numpy())
        self.log(f"Matriz de interacciones de {self.interactions.get_shape()}.")

        # Division de train/test
        self.train_interactions, self.test_interactions = random_train_test_split(
            self.interactions,
            test_percentage=test_percentage,
            random_state=np.random.RandomState(42)
        )
        self.log(f"División train/test: {self.train_interactions.get_shape()} (train) y {self.test_interactions.get_shape()} (test).")

        # Creamos el modelo de LightFM
        self.model = LightFM(
            loss='warp',
            no_components=30,
            learning_rate=0.05,
            random_state=np.random.RandomState(42)
        )
    
    def fit(self, epochs: int = 10):
        """
        Entrena el modelo de LightFM.
        """
        self.log(f"Entrenando el modelo por {epochs} épocas...")
        self.model.fit(
            self.train_interactions,
            epochs=epochs,
            num_threads=16,
            verbose=self.verbose
        )
        self.log("Entrenamiento completado.")
    
    def evaluate(self) -> dict:
        """
        Evalúa el modelo y retorna las métricas evaluadas.
        """
        self.log("Iniciando evaluación del modelo...")
        results = {}

        with Timer() as test_time:
            results["precision@10"] = precision_at_k(self.model, self.test_interactions,
                                                self.train_interactions, k=10, num_threads=16).mean()
            results["recall@10"] = recall_at_k(self.model, self.test_interactions,
                                                self.train_interactions, k=10, num_threads=16).mean()
        self.log(f"Evaluación de precisión y recall: {test_time.interval:.1f} segundos.")

        
        self.log(f'Precisión@10 en test: {results["precision@10"]:.4f}')
        self.log(f'Recall@10 en test: {results["recall@10"]:.4f}')

        return results

    def recommend(self, user_id, num_items: int = 10) -> pd.DataFrame:
        """
        Recomienda recetas para un usuario dado.
        """
        self.log(f"Recomendando {num_items} recetas para el usuario {user_id}...")
        scores = self.model.predict(user_id, np.arange(self.num_items))
        rid_to_iid_map = self.dataset.mapping()[2]
        recipe_id_map = {v: k for k, v in rid_to_iid_map.items()}
        # Obtenemos los IDs de las recetas
        top_items = np.argsort(-scores)[:num_items]
        # Convertimos los índices a IDs de recetas
        top_items = [recipe_id_map[item] for item in top_items]
        
        # Convertimos a DataFrame
        recommendations = pd.DataFrame({
            'recipe_id': top_items[:num_items],
            'score': scores[np.argsort(-scores)][:num_items]
        })
        
        return recommendations
    
    def log(self, message: str):
        """
        Método para imprimir mensajes de log.
        """
        if self.verbose:
            print(f"[FoodRec] {message}")

# Instanciar y entrenar el recomendador
recommender = FoodRecommenderV2(df_ratings, df_recipes, verbose=True)
recommender.fit(epochs=10)
results = recommender.evaluate()

# Mostrar recomendaciones para un usuario específico
user_id = 0
recommendations = recommender.recommend(user_id, num_items=10)
display(df_recipes[df_recipes['recipe_id'].isin(recommendations['recipe_id'])][['recipe_id', 'Name', 'RecipeCategory']].merge(recommendations, on='recipe_id').sort_values(by='score', ascending=False))
# Out:
# [FoodRec] Ratings filtrados: 530,589
# [FoodRec] Dataset creado con 271,907 usuarios y 271,678 recetas.
# [FoodRec] Matriz de interacciones de (271907, 271678).
# [FoodRec] División train/test: (271907, 271678) (train) y (271907, 271678) (test).
# [FoodRec] Entrenando el modelo por 10 épocas...
# Epoch: 100%|██████████| 10/10 [00:01<00:00,  6.47it/s]
# [FoodRec] Entrenamiento completado.
# [FoodRec] Iniciando evaluación del modelo...
# [FoodRec] Evaluación de precisión y recall: 70.2 segundos.
# [FoodRec] Precisión@10 en test: 0.0156
# [FoodRec] Recall@10 en test: 0.0223
# [FoodRec] Recomendando 10 recetas para el usuario 0...
#    recipe_id                                               Name  \
# 4      45809                                    Bourbon Chicken
# 1      27208                         To Die for Crock Pot Roast
# 9      89204  Crock-Pot Chicken With Black Beans &amp; Cream...
# 2      32204    &quot;Whatever Floats Your Boat&quot; Brownies!
# 8      69173   Kittencal's Italian Melt-In-Your-Mouth Meatballs
# 3      39087                         Creamy Cajun Chicken Pasta
# 5      54257            Yes, Virginia There is a Great Meatloaf
# 6      67256   Best Ever Banana Cake With Cream Cheese Frosting
# 0      25690                                           Pancakes
# 7      68955                             Japanese Mum's Chicken
#
#         RecipeCategory     score
# 4       Chicken Breast  1.867039
# 1        One Dish Meal  1.705763
# 9        One Dish Meal  1.695655
# 2           Bar Cookie  1.690492
# 8                 Meat  1.638588
# 3       Chicken Breast  1.638141
# 5             Meatloaf  1.629452
# 6              Dessert  1.606572
# 0            Breakfast  1.600838
# 7  Chicken Thigh & Leg  1.579192

# %% [markdown]
# ## Experimentos (no finalizados)

# %%
# Extraemos un set con todas las keywords que existen en el dataset
keywords_set = set()
for keywords in tqdm(df_recipes["Keywords"].dropna()):
    for k in keywords:
        if isinstance(k, str):
            keywords_set.add(k.lower())
print(f"Total de keywords únicas: {len(keywords_set)}")

# Extraemos un set con todas las categorías de recetas
categories_set = set()
for category in tqdm(df_recipes["RecipeCategory"].dropna()):
    categories_set.add(category.lower())
print(f"Total de categorías únicas: {len(categories_set)}")

# Extraemos un set con todos los ingredientes que existen en el dataset
ingredients_set = set()
for ingredients in tqdm(df_recipes["RecipeIngredientParts"].dropna()):
    for ingredient in ingredients:
        ingredients_set.add(ingredient.lower())
print(f"Total de ingredientes únicos: {len(ingredients_set)}")

# Merge con metadatos de receta

# Creamos en df_recipes la flag is_vegan:
#df_recipes['RecipeCategory'] = df_recipes['RecipeCategory'].fillna('').astype(str)
#df_recipes['is_vegan'] = df_recipes['RecipeCategory'].str.contains(
#    'Vegan', case=False, na=False
#).astype(int)

# Hacemos merge de df_ratings_filt con df_recipes
#df_all = df_ratings_filt.merge(
#    df_recipes[['recipe_id']],
#    on='recipe_id',
#    how='left'
#)

# Comprobamos NA en nutritional cols (si hay, se rellenan con 0)
#df_all[nutri_cols] = df_all[nutri_cols].fillna(0.0)
#df_all['is_vegan'] = df_all['is_vegan'].fillna(0).astype(int)

#df_all.info()
# Out:
#   0%|          | 0/522517 [00:00<?, ?it/s]
# Total de keywords únicas: 314
#   0%|          | 0/521766 [00:00<?, ?it/s]
# Total de categorías únicas: 311
#   0%|          | 0/522517 [00:00<?, ?it/s]
# Total de ingredientes únicos: 7309
